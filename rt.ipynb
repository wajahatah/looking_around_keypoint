# %%
from ultralytics import YOLO

# Load your trained YOLOv8-pose model
model = YOLO("bestv7-2.pt")

# Export the model to TensorRT engine format
model.export(format="engine", batch=10)
# Out:
# WARNING  TensorRT requires GPU export, automatically assigning device=0
# Ultralytics 8.3.38  Python-3.10.16 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# YOLO11l-pose summary (fused): 483 layers, 26,134,189 parameters, 0 gradients, 90.3 GFLOPs
#
# PyTorch: starting from 'bestv7-2.pt' with input shape (10, 3, 640, 640) BCHW and output shape(s) (10, 35, 8400) (100.6 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.48...
# ONNX: export success  5.1s, saved as 'bestv7-2.onnx' (100.1 MB)
#
# TensorRT: starting export with TensorRT 10.9.0.34...
# TensorRT: input "images" with shape(10, 3, 640, 640) DataType.FLOAT
# TensorRT: output "output0" with shape(10, 35, 8400) DataType.FLOAT
# TensorRT: building FP32 engine as bestv7-2.engine
# TensorRT: export success  205.2s, saved as 'bestv7-2.engine' (126.0 MB)
#
# Export complete (205.8s)
# Results saved to C:\wajahat\looking_around_keypoint
# Predict:         yolo predict task=pose model=bestv7-2.engine imgsz=640
# Validate:        yolo val task=pose model=bestv7-2.engine imgsz=640 data=/home/haithem-ge/wajahat/pose/data.yaml
# Visualize:       https://netron.app
# 'bestv7-2.engine'

# %%
import os
import cv2
import numpy as np
import math
import time
from ultralytics import YOLO

def visual_region(center_point, angle):
    length = center_point[1] / 3
    angle_rad = np.radians(angle)
    left_end_point = (
        int(center_point[0] - length * np.sin(angle_rad)),
        int(center_point[1] - length * np.cos(angle_rad))
    )
    right_end_point = (
        int(center_point[0] + length * np.sin(angle_rad)),
        int(center_point[1] - length * np.cos(angle_rad))
    )
    return left_end_point, right_end_point

def get_angle(x1, y1, x2, y2):
    if x1 == x2:
        return 0
    angle_rad = np.arctan2(y2 - y1, x2 - x1) * (180 / np.pi)
    return angle_rad

if __name__ == "__main__":
    model = YOLO("bestv7-2.engine", task="pose")  # Load TensorRT engine
    video_path = "C:/Users/LAMBDA THETA/Videos/evaluation/chunk_06-03-25_13-32-desk21-22-23-24 - Trim.avi"
    cap = cv2.VideoCapture(video_path)
    ymin, ymax = 120, 900
    allowed_angle = 60

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        start_time = time.time()
        results = model(frame)

        for result in results:
            keypoints = result.keypoints
            if keypoints is not None:
                keypoints_data = keypoints.data
                for person_keypoints in keypoints_data:
                    for kp in person_keypoints:
                        x, y, confidence = kp
                        if confidence > 0.5:
                            cv2.circle(frame, (int(x), int(y)), 3, (0, 255, 0), -1)

                    A = person_keypoints[2]
                    B = person_keypoints[3]
                    Ax, Ay = A[0].item(), A[1].item()
                    Bx, By = B[0].item(), B[1].item()
                    cv2.line(frame, (int(Ax), int(Ay)), (int(Bx), int(By)), (0, 255, 0), 2)

                    angle = get_angle(Ax, Ay, Bx, By)
                    center = (int((Ax + Bx) / 2), int((Ay + By) / 2))
                    diff = (ymax - ymin) / 2
                    LA_angle_threshold = allowed_angle - int(((By + Ay) / 2 - diff) / (ymax - diff) * 30)
                    left_point, right_point = visual_region(center, LA_angle_threshold)
                    cv2.line(frame, center, left_point, (255, 255, 255), 4)
                    cv2.line(frame, center, right_point, (255, 255, 255), 4)

                    if abs(angle) >= LA_angle_threshold:
                        cv2.putText(frame, "Looking around", (center[0], center[1] - 10),
                                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 4)

        # fps = 1.0 / (time.time() - start_time + 1e-4)
        # cv2.putText(frame, f"FPS: {fps:.2f}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
        resized_frame = cv2.resize(frame, (1280, 640))
        cv2.imshow('Pose Detection', resized_frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
        
        print("fps =", 1.0 / (time.time() - start_time + 0.0001))
        
    cap.release()
    cv2.destroyAllWindows()
# Out:
# Loading bestv7-2.engine for TensorRT inference...
#
# 0: 640x640 1 person, 15.0ms
# Speed: 26.0ms preprocess, 15.0ms inference, 67.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 0.7208992695665472
#
# 0: 640x640 1 person, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 36.19853817802146
#
# 0: 640x640 1 person, 17.4ms
# Speed: 1.0ms preprocess, 17.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 35.098945542756326
#
# 0: 640x640 1 person, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 35.58583353574668
#
# 0: 640x640 1 person, 16.5ms
# Speed: 1.0ms preprocess, 16.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# fps = 35.687569260688434
#
# 0: 640x640 1 person, 17.8ms
# Speed: 2.0ms preprocess, 17.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# fps = 32.13793813324313
#
# 0: 640x640 1 person, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 33.2236755848201
#
# 0: 640x640 1 person, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 35.580399774316156
#
# 0: 640x640 1 person, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 34.32118641453736
#
# 0: 640x640 1 person, 13.9ms
# Speed: 2.0ms preprocess, 13.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 38.451127608242295
#
# 0: 640x640 1 person, 12.1ms
# Speed: 2.0ms preprocess, 12.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 42.16718795232945
#
# 0: 640x640 1 person, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# fps = 39.01299608228524
#
# 0: 640x640 1 person, 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 39.10538495787941
#
# 0: 640x640 1 person, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 38.31764288729777
#
# 0: 640x640 1 person, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 41.48774091888294
#
# 0: 640x640 1 person, 12.2ms
# Speed: 2.0ms preprocess, 12.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 41.20893156557564
#
# 0: 640x640 1 person, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 39.159785500745244
#
# 0: 640x640 1 person, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 40.809185192616056
#
# 0: 640x640 1 person, 12.2ms
# Speed: 1.6ms preprocess, 12.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 41.74831317586058
#
# 0: 640x640 1 person, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.30970797882869
#
# 0: 640x640 1 person, 13.3ms
# Speed: 1.0ms preprocess, 13.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 40.90111262310089
#
# 0: 640x640 1 person, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 40.907894208937215
#
# 0: 640x640 1 person, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 42.639153863675595
#
# 0: 640x640 1 person, 11.5ms
# Speed: 2.5ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.2436220301167
#
# 0: 640x640 1 person, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 41.4668224055803
#
# 0: 640x640 1 person, 12.8ms
# Speed: 1.0ms preprocess, 12.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.0055213364601
#
# 0: 640x640 1 person, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 44.20201472723774
#
# 0: 640x640 1 person, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# fps = 44.666142462884935
#
# 0: 640x640 1 person, 12.0ms
# Speed: 1.5ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 42.98128280103175
#
# 0: 640x640 1 person, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.286912320686696
#
# 0: 640x640 1 person, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 47.21963047195097
#
# 0: 640x640 1 person, 13.3ms
# Speed: 2.1ms preprocess, 13.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 46.27358572664361
#
# 0: 640x640 1 person, 11.3ms
# Speed: 2.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 46.185943879948404
#
# 0: 640x640 1 person, 13.2ms
# Speed: 2.0ms preprocess, 13.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.94774707024101
#
# 0: 640x640 1 person, 12.1ms
# Speed: 1.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 47.07441990560694
#
# 0: 640x640 1 person, 12.5ms
# Speed: 1.2ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 47.061743260726196
#
# 0: 640x640 2 persons, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 44.271064752680786
#
# 0: 640x640 1 person, 12.4ms
# Speed: 2.1ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 48.55337272244464
#
# 0: 640x640 1 person, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 42.532355386397896
#
# 0: 640x640 1 person, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 46.333904730150394
#
# 0: 640x640 1 person, 14.8ms
# Speed: 1.0ms preprocess, 14.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 39.74233581491482
#
# 0: 640x640 1 person, 12.4ms
# Speed: 1.0ms preprocess, 12.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 42.2870747851815
#
# 0: 640x640 1 person, 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 42.33146061382846
#
# 0: 640x640 1 person, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.265925794243344
#
# 0: 640x640 1 person, 13.4ms
# Speed: 1.0ms preprocess, 13.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.53763622908506
#
# 0: 640x640 1 person, 12.4ms
# Speed: 1.4ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.392151086469816
#
# 0: 640x640 1 person, 12.7ms
# Speed: 1.0ms preprocess, 12.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.762496239869975
#
# 0: 640x640 1 person, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.281998755781224
#
# 0: 640x640 1 person, 11.4ms
# Speed: 1.0ms preprocess, 11.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# fps = 44.52862563969217
#
# 0: 640x640 1 person, 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 42.49486540369328
#
# 0: 640x640 1 person, 11.4ms
# Speed: 2.0ms preprocess, 11.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.84484047145848
#
# 0: 640x640 1 person, 12.7ms
# Speed: 1.0ms preprocess, 12.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 41.32993911881008
#
# 0: 640x640 1 person, 11.9ms
# Speed: 1.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 44.25331511593469
#
# 0: 640x640 1 person, 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 44.22998200356163
#
# 0: 640x640 1 person, 11.9ms
# Speed: 1.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 44.42204302897383
#
# 0: 640x640 1 person, 11.8ms
# Speed: 1.0ms preprocess, 11.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 45.66052328279278
#
# 0: 640x640 1 person, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 44.71375921023886
#
# 0: 640x640 1 person, 11.6ms
# Speed: 2.2ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.60870483274527
#
# 0: 640x640 1 person, 12.4ms
# Speed: 1.0ms preprocess, 12.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# fps = 45.46797652588055
#
# 0: 640x640 1 person, 11.2ms
# Speed: 1.0ms preprocess, 11.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.870980784790234
#
# 0: 640x640 1 person, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 44.224385717404786
#
# 0: 640x640 1 person, 12.1ms
# Speed: 2.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 42.89863699654949
#
# 0: 640x640 1 person, 13.1ms
# Speed: 2.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 41.35683563917234
#
# 0: 640x640 1 person, 11.0ms
# Speed: 2.8ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.50376795397121
#
# 0: 640x640 1 person, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 44.16524504336759
#
# 0: 640x640 1 person, 12.2ms
# Speed: 1.0ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 44.76577724090631
#
# 0: 640x640 1 person, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.59827900689911
#
# 0: 640x640 1 person, 12.6ms
# Speed: 1.0ms preprocess, 12.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 44.13085800044945
#
# 0: 640x640 1 person, 11.9ms
# Speed: 1.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 44.391483149587785
#
# 0: 640x640 1 person, 12.4ms
# Speed: 1.0ms preprocess, 12.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 44.15222742937929
#
# 0: 640x640 1 person, 12.2ms
# Speed: 2.0ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 49.17960758746432
#
# 0: 640x640 1 person, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 47.40106909170891
#
# 0: 640x640 1 person, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 44.51350322513358
#
# 0: 640x640 1 person, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 44.95000164526087
#
# 0: 640x640 1 person, 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 47.12095942230808
#
# 0: 640x640 1 person, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 47.376975137805275
#
# 0: 640x640 1 person, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 47.376975137805275
#
# 0: 640x640 1 person, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.26547949349232
#
# 0: 640x640 1 person, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.19908341690868
#
# 0: 640x640 1 person, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 44.442753608888445
#
# 0: 640x640 1 person, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 49.74893057752173
#
# 0: 640x640 1 person, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 47.405890823552035
#
# 0: 640x640 1 person, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 48.503962206638676
#
# 0: 640x640 1 person, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 45.22529743839881
#
# 0: 640x640 1 person, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 45.24676396246727
#
# 0: 640x640 1 person, 11.3ms
# Speed: 2.0ms preprocess, 11.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 42.69427549250639
#
# 0: 640x640 1 person, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.29808366372242
#
# 0: 640x640 1 person, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 48.5202341040586
#
# 0: 640x640 1 person, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 47.39892641460601
#
# 0: 640x640 1 person, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 47.37643999480664
#
# 0: 640x640 1 person, 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# fps = 47.39410609930999
#
# 0: 640x640 1 person, 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 44.207605352684595
#
# 0: 640x640 1 person, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 45.23310109002104
#
# 0: 640x640 1 person, 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.23292438926922
#
# 0: 640x640 1 person, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.30434213483053
#
# 0: 640x640 1 person, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 44.19875418201189
#
# 0: 640x640 1 person, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.27619325340154
#
# 0: 640x640 1 person, 12.2ms
# Speed: 1.0ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 44.76625503083299
#
# 0: 640x640 1 person, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.278425954614086
#
# 0: 640x640 1 person, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 46.64409786790936
#
# 0: 640x640 1 person, 12.0ms
# Speed: 1.5ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 42.332315100641715
#
# 0: 640x640 1 person, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.277532846484206
#
# 0: 640x640 1 person, 12.1ms
# Speed: 2.3ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 44.31503298371638
#
# 0: 640x640 1 person, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.28333870830645
#
# 0: 640x640 1 person, 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 44.25751769087671
#
# 0: 640x640 1 person, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 47.374834638344275
#
# 0: 640x640 1 person, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 47.372159285994236
#
# 0: 640x640 1 person, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.51640594433601
#
# 0: 640x640 1 person, 11.3ms
# Speed: 2.1ms preprocess, 11.3ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
# fps = 49.857149293713526
#
# 0: 640x640 1 person, 12.0ms
# Speed: 2.1ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 45.06300877649472
#
# 0: 640x640 1 person, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 45.25457502461006
#
# 0: 640x640 1 person, 12.2ms
# Speed: 2.0ms preprocess, 12.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 42.83686091749881
#
# 0: 640x640 1 person, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 45.25457502461006
#
# 0: 640x640 1 person, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 44.21879084723118
#
# 0: 640x640 1 person, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 45.247252074853634
#
# 0: 640x640 1 person, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 44.42204302897383
#
# 0: 640x640 1 person, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.26771108932665
#
# 0: 640x640 1 person, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 46.29043877577202
#
# 0: 640x640 1 person, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 48.84798024584578
#
# 0: 640x640 1 person, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 45.25311024503804
#
# 0: 640x640 1 person, 12.4ms
# Speed: 1.4ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.52905127959161
#
# 0: 640x640 1 person, 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 46.251134074123556
#
# 0: 640x640 1 person, 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 47.09344768287748
#
# 0: 640x640 1 person, 11.0ms
# Speed: 2.2ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 47.04749019360876
#
# 0: 640x640 1 person, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 49.75483203264918
#
# 0: 640x640 1 person, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# fps = 44.69993990478584
#
# 0: 640x640 1 person, 11.0ms
# Speed: 1.6ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.73876545806147
#
# 0: 640x640 1 person, 11.3ms
# Speed: 2.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 42.8036369114357
#
# 0: 640x640 1 person, 12.4ms
# Speed: 1.0ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 44.48753555965948
#
# 0: 640x640 1 person, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.27172854200534
#
# 0: 640x640 1 person, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 44.112292695454705
#
# 0: 640x640 1 person, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 45.235540283468275
#
# 0: 640x640 1 person, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.27663977521452
#
# 0: 640x640 1 person, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.34641019930397
#
# 0: 640x640 1 person, 11.2ms
# Speed: 2.0ms preprocess, 11.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 44.91534416092902
#
# 0: 640x640 1 person, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 41.476253632834975
#
# 0: 640x640 1 person, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.27663977521452
#
# 0: 640x640 1 person, 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 44.86009917123883
#
# 0: 640x640 1 person, 11.2ms
# Speed: 2.0ms preprocess, 11.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 0.39313860954426616
#
# 0: 640x640 1 person, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 41.504983783632476
#
# 0: 640x640 1 person, 15.0ms
# Speed: 1.9ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 37.05856202504775
#
# 0: 640x640 1 person, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 38.11221703121089
#
# 0: 640x640 1 person, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 39.84086451320257
#
# 0: 640x640 1 person, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 39.82875809722447
#
# 0: 640x640 1 person, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 36.87999548791803
#
# 0: 640x640 1 person, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 34.910224933531886
#
# 0: 640x640 1 person, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 45.25066915645696
#
# 0: 640x640 1 person, 13.2ms
# Speed: 2.0ms preprocess, 13.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 45.67046694648214
#
# 0: 640x640 1 person, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 42.76784770949971
#
# 0: 640x640 1 person, 11.7ms
# Speed: 2.0ms preprocess, 11.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.62594103924379
#
# 0: 640x640 1 person, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 41.49307646491917
#
# 0: 640x640 1 person, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 41.48035550467281
#
# 0: 640x640 1 person, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 41.44920161144397
#
# 0: 640x640 1 person, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 39.816659036547854
#
# 0: 640x640 1 person, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.247635010444014
#
# 0: 640x640 1 person, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 42.36609494482617
#
# 0: 640x640 1 person, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.278425954614086
#
# 0: 640x640 1 person, 14.7ms
# Speed: 1.0ms preprocess, 14.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 40.31146164662996
#
# 0: 640x640 1 person, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.82514119073436
#
# 0: 640x640 1 person, 12.5ms
# Speed: 1.1ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 42.20028007847323
#
# 0: 640x640 1 person, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 42.96323184250976
#
# 0: 640x640 1 person, 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 38.21221680768461
#
# 0: 640x640 1 person, 13.4ms
# Speed: 1.0ms preprocess, 13.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 42.54357213095463
#
# 0: 640x640 1 person, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# fps = 43.27306785869213
#
# 0: 640x640 (no detections), 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 52
#      49     if confidence > 0.5:
#      50         cv2.circle(frame, (int(x), int(y)), 3, (0, 255, 0), -1)
# ---> 52 A = person_keypoints[2]
#      53 B = person_keypoints[3]
#      54 Ax, Ay = A[0].item(), A[1].item()
#
# IndexError: index 2 is out of bounds for dimension 0 with size 0
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
